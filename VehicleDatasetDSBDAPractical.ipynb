# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv('/content/car data.csv')

# %%
dataFrame.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
dataFrame.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
dataFrame.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df1 = dataFrame.copy()
df2 = dataFrame.copy()
df3 = dataFrame.copy()

# %%
dataFrame.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
dataFrame.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
dataFrame.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
dataFrame.columns[0]
# Out:
# 'Car_Name'

# %%
dataFrame[dataFrame['Car_Name']=='ritz'].head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      ritz  2014           3.35           5.59       27000    Petrol
# 30     ritz  2012           3.10           5.98       51439    Diesel
# 31     ritz  2011           2.35           4.89       54200    Petrol
# 46     ritz  2013           2.65           4.89       64532    Petrol
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 30      Dealer       Manual      0
# 31      Dealer       Manual      0
# 46      Dealer       Manual      0

# %%
dataFrame.loc[0]
# Out:
# Car_Name           ritz
# Year               2014
# Selling_Price      3.35
# Present_Price      5.59
# Kms_Driven        27000
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 0, dtype: object

# %%
dataFrame.loc[10:20]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 10  alto 800  2017           2.85           3.60        2135    Petrol
# 11      ciaz  2015           6.85          10.38       51000    Diesel
# 12      ciaz  2015           7.50           9.94       15000    Petrol
# 13    ertiga  2015           6.10           7.71       26000    Petrol
# 14     dzire  2009           2.25           7.21       77427    Petrol
# 15    ertiga  2016           7.75          10.79       43000    Diesel
# 16    ertiga  2015           7.25          10.79       41678    Diesel
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 18   wagon r  2015           3.25           5.09       35500       CNG
# 19       sx4  2010           2.65           7.98       41442    Petrol
# 20  alto k10  2016           2.85           3.95       25000    Petrol
#
#    Seller_Type Transmission  Owner
# 10      Dealer       Manual      0
# 11      Dealer       Manual      0
# ...

# %%
dataFrame.shape
# Out:
# (301, 9)

# %%
dataFrame.shape[0]
# Out:
# 301

# %%
dataFrame.iloc[0]
# Out:
# Car_Name           ritz
# Year               2014
# Selling_Price      3.35
# Present_Price      5.59
# Kms_Driven        27000
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 0, dtype: object

# %%
dataFrame.loc[0]
# Out:
# Car_Name           ritz
# Year               2014
# Selling_Price      3.35
# Present_Price      5.59
# Kms_Driven        27000
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 0, dtype: object

# %%
dataFrame.iloc[0,0]
# Out:
# 'ritz'

# %%
dataFrame.iloc[10:15,0]
# Out:
# 10    alto 800
# 11        ciaz
# 12        ciaz
# 13      ertiga
# 14       dzire
# Name: Car_Name, dtype: object

# %% [markdown]
# iloc is used to track the individual rows and columns

# %%
column_list = ['Car_Name','Year','Selling_Price']
dataFrame[column_list]
# Out:
#     Car_Name  Year  Selling_Price
# 0       ritz  2014           3.35
# 1        sx4  2013           4.75
# 2       ciaz  2017           7.25
# 3    wagon r  2011           2.85
# 4      swift  2014           4.60
# ..       ...   ...            ...
# 296     city  2016           9.50
# 297     brio  2015           4.00
# 298     city  2009           3.35
# 299     city  2017          11.50
# 300     brio  2016           5.30
#
# [301 rows x 3 columns]

# %%
newDataFrame = dataFrame.iloc[10:20,0:5]

# %%
newDataFrame.head()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven
# 10  alto 800  2017           2.85           3.60        2135
# 11      ciaz  2015           6.85          10.38       51000
# 12      ciaz  2015           7.50           9.94       15000
# 13    ertiga  2015           6.10           7.71       26000
# 14     dzire  2009           2.25           7.21       77427

# %%
newDataFrame.shape
# Out:
# (10, 5)

# %%
newDataFrame['discount'] = 0

# %%
newDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 10 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       10 non-null     object
#  1   Year           10 non-null     int64
#  2   Selling_Price  10 non-null     float64
#  3   Present_Price  10 non-null     float64
#  4   Kms_Driven     10 non-null     int64
#  5   discount       10 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 612.0+ bytes

# %%
newDataFrame.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# discount         0
# dtype: int64

# %%
newDataFrame.drop(['discount'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-71d79ffa1528> in <cell line: 1>()
# ----> 1 newDataFrame.drop(['discount'], axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
newDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 10 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       10 non-null     object
#  1   Year           10 non-null     int64
#  2   Selling_Price  10 non-null     float64
#  3   Present_Price  10 non-null     float64
#  4   Kms_Driven     10 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 532.0+ bytes

# %%
newDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 10 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       10 non-null     object
#  1   Year           10 non-null     int64
#  2   Selling_Price  10 non-null     float64
#  3   Present_Price  10 non-null     float64
#  4   Kms_Driven     10 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 532.0+ bytes

# %%
newDataFrame['newDiscount'] = newDataFrame['Selling_Price']*0.2

# %%
newDataFrame.head()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  newDiscount
# 10  alto 800  2017           2.85           3.60        2135         0.57
# 11      ciaz  2015           6.85          10.38       51000         1.37
# 12      ciaz  2015           7.50           9.94       15000         1.50
# 13    ertiga  2015           6.10           7.71       26000         1.22
# 14     dzire  2009           2.25           7.21       77427         0.45

# %%
newDataFrame['Selling_Price'].dtype
# Out:
# dtype('float64')

# %%
newDataFrame['Car_Name'].dtype
# Out:
# dtype('O')

# %%
dataFrame['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
dataFrame[dataFrame['Car_Name']=='ritz']
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      ritz  2014           3.35           5.59       27000    Petrol
# 30     ritz  2012           3.10           5.98       51439    Diesel
# 31     ritz  2011           2.35           4.89       54200    Petrol
# 46     ritz  2013           2.65           4.89       64532    Petrol
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 30      Dealer       Manual      0
# 31      Dealer       Manual      0
# 46      Dealer       Manual      0

# %%
dataFrame2 = dataFrame[dataFrame['Car_Name']=='ritz']

# %%
dataFrame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       4 non-null      object
#  1   Year           4 non-null      int64
#  2   Selling_Price  4 non-null      float64
#  3   Present_Price  4 non-null      float64
#  4   Kms_Driven     4 non-null      int64
#  5   Fuel_Type      4 non-null      object
#  6   Seller_Type    4 non-null      object
#  7   Transmission   4 non-null      object
#  8   Owner          4 non-null      int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 320.0+ bytes

# %%
dataFrame2.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      ritz  2014           3.35           5.59       27000    Petrol
# 30     ritz  2012           3.10           5.98       51439    Diesel
# 31     ritz  2011           2.35           4.89       54200    Petrol
# 46     ritz  2013           2.65           4.89       64532    Petrol
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 30      Dealer       Manual      0
# 31      Dealer       Manual      0
# 46      Dealer       Manual      0

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
dataFrame['Selling_Price'].describe()
# Out:
# count    301.000000
# mean       4.661296
# std        5.082812
# min        0.100000
# 25%        0.900000
# 50%        3.600000
# 75%        6.000000
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
dataFrame[(dataFrame['Selling_Price']>10) & (dataFrame['Selling_Price']<25)]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50        fortuner  2012          14.90          30.61      104707    Diesel
# 51        fortuner  2015          23.00          30.61       40000    Diesel
# 52          innova  2017          18.00          19.77       15000    Diesel
# 53        fortuner  2013          16.00          30.61      135000    Diesel
# 59        fortuner  2014          19.99          35.96       41000    Diesel
# 62        fortuner  2014          18.75          35.96       78000    Diesel
# 63        fortuner  2015          23.50          35.96       47000    Diesel
# 66          innova  2017          19.75          23.15       11000    Petrol
# 69   corolla altis  2016          14.25          20.91       12000    Petrol
# 79        fortuner  2012          14.50          30.61       89000    Diesel
# 80   corolla altis  2016          14.73          14.89       23000    Diesel
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone the repository
# !git clone https://github.com/darshancodes2612/DSBDAPracticalSPPY.git

# Change to the repository directory
# %cd DSBDAPracticalSPPY
# Out:
# Cloning into 'DSBDAPracticalSPPY'...
# ...
# /content/DSBDAPracticalSPPY

# %%
# !git config --global user.email "joshi.darshan1826@gmail.com"
# !git config --global user.name "darshancodes2612"

# %%
# !git add .
# !git commit -m "DSBDA First Practical"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/darshancodes2612/DSBDAPracticalSPPY.git'

# %%
# !git branch
